# %%
import pandas as pd
from collections import Counter
import re
import os
import spacy
import tokenize_to_counter
nlp = spacy.load("en_core_web_lg")

# %%
TEST_PATH_FOR_FILE = "../data/test/1.txt"
TEST_PATH_FOR_DIR = "../data/test/"

# %%
def extract_and_save(DIR_PATH):
    files = []
    for file in os.listdir(DIR_PATH):
        x = ""
        with open(os.path.join(DIR_PATH + file)) as f:
            for line in f.readlines():
                x += line
        files.append(x)
    extracted_data = pd.DataFrame()
    extracted_data["docs"] = files
    return extracted_data

# %%
df = extract_and_save(TEST_PATH_FOR_DIR)

# %%
def map_dataframe_to_counter(df):
    df["docs"] = df["docs"].apply(lambda x : tokenize_to_counter.solve(x))
    return df

# %%
df_2 = map_dataframe_to_counter(df)

# %%
df_2["docs"][1]
# Out:
# Counter({'\n \n': 10,
#          '\n \n \n \n \n': 1,
#          '\n \n \n \n \n \n \n ': 1,
#          'gopala': 2,
#          'gowda': 2,
#          'justice': 4,
#          'leave': 1,
#          'granted': 1,
#          'appeal': 20,
#          'filed': 2,
#          'appellants': 18,
#          'questioning': 1,
#          'correctness': 1,
#          'common': 1,
#          'judgment': 4,
#          'final': 1,
#          'order': 4,
#          'dated': 2,
#          'passed': 1,
#          'high': 23,
#          'court': 42,
#          'karnataka': 3,
#          'bangalore': 1,
#          'm.f.a': 2,
#          'nos': 2,
#          'urging': 1,
#          'facts': 5,
#          'legal': 5,
#          'contentions': 1,
#          'justification': 1,
#          'claim': 14,
#          'necessary': 2,
#          'relevant': 5,
#          'stated': 5,
#          'hereunder': 1,
#          'appreciate': 1,
#          'case': 19,
#          'find': 7,
#          'entitled': 16,
#          'relief': 1,
#          'prayed': 1,
#          'appeals': 8,
#          'claimants': 13,
#          'proceeding': 1,
#          'left': 2,
#          'road': 4,
#          'pushing': 1,
#          'motorcycle': 1,
#          'bearing': 3,
#          'registration': 2,
#          'punctured': 1,
#          'came': 3,
#          'near': 1,
#          'coper': 1,
#          'petrol': 1,
#          'bunk': 1,
#          'opposite': 2,
#          'jai': 1,
#          'hind': 1,
#          'hotel': 1,
#          'tractor': 3,
#          'direction': 1,
#          'right': 8,
#          'rash': 2,
#          'negligent': 2,
#          'manner': 1,
#          'dashed': 1,
#          'motor': 3,
#          'cycle': 1,
#          'resulted': 1,
#          'sustaining': 2,
#          'grievous': 1,
#          'injuries': 8,
#          'respectively': 4,
#          'accident': 16,
#          'tribunal': 30,
#          'chitradurga': 1,
#          'short': 1,
#          'awarded': 15,
#          'different': 4,
#          'awards': 1,
#          'heard': 1,
#          'suffered': 6,
#          'inclined': 5,
#          'decide': 1,
#          'individually': 1,
#          'far': 1,
#          'sustained': 9,
#          'concerned': 1,
#          'dispute': 2,
#          'occurred': 1,
#          'driving': 1,
#          'trailer': 1,
#          'driver': 1,
#          'confined': 2,
#          'determining': 3,
#          'quantum': 1,
#          'compensation': 16,
#          'enhanced': 1,
#          'proper': 5,
#          'requires': 3,
#          'enhancement': 2,
#          'interest': 8,
#          'time': 10,
#          'civil': 7,
#          'mfa': 7,
#          'mvc': 6,
#          'evident': 6,
#          'material': 5,
#          'evidence': 18,
#          'produced': 7,
#          'record': 5,
#          'appellant': 49,
#          'claimant': 57,
#          'lower': 5,
#          'end': 1,
#          'femur': 2,
#          'leg': 4,
#          'amputated': 2,
#          'injury': 1,
#          'upper': 4,
#          'arm': 1,
#          'treatment': 3,
#          'taken': 5,
#          'wound': 2,
#          'certificate': 5,
#          'discharge': 2,
#          'cards': 1,
#          'ex.p': 2,
#          'disability': 21,
#          'ray': 3,
#          'films': 2,
#          'supported': 3,
#          'oral': 3,
#          'doctor': 5,
#          'examined': 3,
#          'prosecuting': 9,
#          'witness': 9,
#          'rajesh': 3,
#          'limb': 6,
#          'considered': 4,
#          'caused': 1,
#          'body': 1,
#          'taking': 1,
#          'consideration': 1,
#          'amputation': 1,
#          'determined': 2,
#          'assigning': 2,
#          'reason': 5,
#          'coming': 1,
#          'conclusion': 2,
#          'intend': 2,
#          'assign': 1,
#          'reasons': 2,
#          'hold': 10,
#          'erred': 4,
#          'concluding': 1,
#          'mohan': 1,
#          'soni': 1,
#          'ram': 1,
#          'avtar': 1,
#          'tomar': 1,
#          'ors': 1,
#          'elaborately': 1,
#          'discussed': 1,
#          'factors': 1,
#          'determine': 6,
#          'loss': 24,
#          'income': 28,
#          'objectively': 1,
#          'paragraph': 3,
#          'reads': 1,
#          'recent': 1,
#          'decision': 1,
#          'rajdhani': 2,
#          'law': 2,
#          'reporter': 2,
#          'kumar': 5,
#          'ajay': 1,
#          'supreme': 4,
#          'cases': 14,
#          'great': 1,
#          'detail': 1,
#          'correlation': 1,
#          'physical': 1,
#          'earning': 20,
#          'capacity': 9,
#          'resulting': 1,
#          'paragraphs': 1,
#          'following': 4,
#          'observations': 2,
#          'suffers': 2,
#          'permanentdisabilityas': 2,
#          'result': 6,
#          'assessment': 2,
#          'head': 12,
#          'future': 13,
#          'earnings': 2,
#          'depend': 1,
#          'effect': 4,
#          'impact': 1,
#          'permanentdisabilityon': 3,
#          'capacity.the': 1,
#          'mechanically': 1,
#          'apply': 1,
#          'percentage': 13,
#          'economic': 2,
#          'arising': 1,
#          'permanentdisabilitywill': 2,
#          'permanentdisability.some': 1,
#          'tribunals': 1,
#          'wrongly': 1,
#          'assume': 1,
#          'particular': 2,
#          'extent': 7,
#          'permanent': 3,
#          'disabilitywould': 1,
#          'corresponding': 2,
#          'consequently': 1,
#          'permanentdisability': 4,
#          'capacity.in': 1,
#          'equating': 1,
#          'award': 2,
#          'low': 2,
#          'assessed': 3,
#          'injured': 1,
#          'assessing': 1,
#          'terms': 2,
#          'quantified': 1,
#          'money': 1,
#          'arrive': 1,
#          'applying': 4,
#          'standard': 1,
#          'multiplier': 7,
#          'method': 1,
#          'dependency': 1,
#          'note': 2,
#          'appreciation': 1,
#          'approximately': 1,
#          'permanentdisabilityin': 1,
#          'course': 1,
#          'adopt': 1,
#          'said': 2,
#          'determination': 1,
#          'example': 2,
#          'decisions': 1,
#          'arvind': 1,
#          'mishra': 1,
#          'new': 2,
#          'india': 1,
#          'assurance': 1,
#          'company': 8,
#          'ltd': 2,
#          'yadava': 1,
#          'national': 2,
#          'insurance': 6,
#          'ascertainment': 1,
#          'actual': 2,
#          'involves': 4,
#          'steps': 1,
#          'ascertain': 2,
#          'activities': 4,
#          'carry': 4,
#          'spite': 2,
#          'permanentdisabilityand': 1,
#          'awarding': 1,
#          'amenities': 2,
#          'life': 3,
#          'second': 1,
#          'step': 2,
#          'avocation': 1,
#          'profession': 3,
#          'nature': 2,
#          'work': 3,
#          'age': 8,
#          'totally': 1,
#          'disabled': 1,
#          'kind': 1,
#          'livelihood': 8,
#          'effectively': 1,
#          'functions': 3,
#          'earlier': 2,
#          'carrying': 1,
#          'prevented': 1,
#          'restricted': 1,
#          'discharging': 1,
#          'previous': 1,
#          'lesser': 1,
#          'almanac': 1,
#          'continues': 1,
#          'earn': 3,
#          'continue': 1,
#          'claims': 1,
#          'working': 5,
#          'vegetable': 7,
#          'vendor': 4,
#          'true': 1,
#          'require': 2,
#          'mobility': 3,
#          'sells': 1,
#          'vegetables': 7,
#          'place': 5,
#          'occupation': 3,
#          'vending': 4,
#          'selling': 4,
#          'location': 1,
#          'procuring': 1,
#          'sale': 1,
#          'market': 4,
#          'farmers': 1,
#          'retail': 1,
#          'cart': 1,
#          'conservative': 1,
#          'approach': 1,
#          'presume': 1,
#          'involved': 3,
#          'assistance': 1,
#          'bringing': 1,
#          'extremely': 2,
#          'difficult': 3,
#          'required': 2,
#          'sensitive': 2,
#          'dealing': 1,
#          'manual': 3,
#          'labour': 7,
#          'equivalent': 1,
#          'considering': 13,
#          'capable': 2,
#          'fend': 1,
#          'brought': 1,
#          'claimed': 2,
#          'pic': 47,
#          'p.m.': 4,
#          'produce': 3,
#          'document': 1,
#          'establish': 1,
#          'convince': 1,
#          'unorganized': 2,
#          'sector': 1,
#          'business': 2,
#          'expected': 1,
#          'documents': 1,
#          'prove': 2,
#          'monthly': 9,
#          'regard': 2,
#          'ramchandrappa': 1,
#          'manager': 1,
#          'royal': 1,
#          'sundaram': 1,
#          'alliance': 1,
#          'limited': 2,
#          'held': 4,
#          'instant': 2,
#          'aged': 1,
#          'years': 17,
#          'coolie': 3,
#          'month': 6,
#          'reduced': 5,
#          'sum': 5,
#          'assumption': 2,
#          'wages': 7,
#          'labourer': 2,
#          'period': 4,
#          'viz': 1,
#          'year': 1,
#          'day': 2,
#          'view': 5,
#          'basis': 6,
#          'served': 1,
#          'choose': 1,
#          'appear': 1,
#          'repudiated': 1,
#          'secondly': 1,
#          'expect': 1,
#          'documentary': 1,
#          'substantiate': 1,
#          'absence': 3,
#          'contrary': 3,
#          'present': 7,
#          'accepted': 1,
#          'hasten': 1,
#          'add': 1,
#          'circumstances': 3,
#          'need': 1,
#          'accept': 3,
#          'supporting': 1,
#          'depends': 1,
#          'given': 3,
#          'exorbitant': 1,
#          'ground': 2,
#          'realities': 2,
#          'proceed': 1,
#          'possible': 1,
#          'resorting': 1,
#          'guess': 1,
#          'include': 2,
#          'prevailing': 1,
#          'point': 1,
#          'date': 8,
#          'wage': 1,
#          'honest': 1,
#          'bonafide': 1,
#          'statement': 1,
#          'ask': 1,
#          'hand': 2,
#          'going': 1,
#          'state': 3,
#          'economy': 1,
#          'rising': 2,
#          'prices': 4,
#          'agricultural': 1,
#          'products': 1,
#          'believe': 1,
#          'reasonably': 1,
#          'old': 1,
#          'occurrence': 1,
#          'established': 2,
#          'issue': 1,
#          'calculation': 1,
#          'prospective': 1,
#          'increment': 7,
#          'self': 8,
#          'employed': 13,
#          'people': 2,
#          'santosh': 3,
#          'devi': 3,
#          'fathom': 1,
#          'rationale': 1,
#          'observation': 1,
#          'sarla': 4,
#          'verma': 4,
#          'deceased': 2,
#          'fixed': 5,
#          'salary': 3,
#          'provision': 2,
#          'annual': 2,
#          'etc': 3,
#          'courts': 1,
#          'usually': 1,
#          'death': 1,
#          'departure': 1,
#          'rule': 4,
#          'rare': 1,
#          'exceptional': 1,
#          'involving': 1,
#          'special': 1,
#          'nave': 1,
#          'total': 7,
#          'emoluments': 3,
#          'person': 3,
#          'remain': 2,
#          'rise': 2,
#          'cost': 9,
#          'living': 4,
#          'affects': 1,
#          'board': 1,
#          'distinction': 1,
#          'rich': 2,
#          'poor': 1,
#          'matter': 2,
#          'fact': 4,
#          'directly': 1,
#          'impacts': 1,
#          'minimal': 1,
#          'maximum': 1,
#          'worst': 1,
#          'affected': 1,
#          'extra': 1,
#          'efforts': 1,
#          'generate': 1,
#          'additional': 1,
#          'families': 2,
#          'salaries': 3,
#          'central': 1,
#          'governments': 1,
#          'agencies': 1,
#          'instrumentalities': 1,
#          'revised': 2,
#          'provide': 1,
#          'cushion': 1,
#          'provisions': 1,
#          'providing': 1,
#          'security': 1,
#          'employees': 2,
#          'private': 3,
#          'sectors': 3,
#          'increased': 1,
#          'manifold': 1,
#          'till': 4,
#          'decades': 1,
#          'ago': 1,
#          'imagined': 1,
#          'class': 1,
#          'employee': 1,
#          'government': 2,
#          'figures': 1,
#          'higher': 1,
#          'echelons': 1,
#          'service': 1,
#          'cross': 1,
#          'figure': 1,
#          'rupees': 1,
#          'lac': 1,
#          'registered': 1,
#          'increase': 6,
#          'kept': 1,
#          'pace': 1,
#          'denied': 1,
#          'incremental': 1,
#          'engaged': 2,
#          'daily': 2,
#          'seasonal': 1,
#          'judicial': 1,
#          'notice': 1,
#          'meet': 1,
#          'challenges': 1,
#          'posed': 1,
#          'persons': 1,
#          'falling': 1,
#          'category': 1,
#          'periodically': 1,
#          'context': 1,
#          'useful': 1,
#          'tailor': 1,
#          'earns': 2,
#          'stitching': 1,
#          'cloths': 1,
#          'increases': 1,
#          'essentials': 1,
#          'natural': 1,
#          'ordinary': 1,
#          'skilled': 1,
#          'unskilled': 1,
#          'like': 2,
#          'barber': 1,
#          'blacksmith': 1,
#          'cobbler': 1,
#          'mason': 1,
#          'think': 1,
#          'making': 1,
#          'lines': 1,
#          'intended': 1,
#          'lay': 1,
#          'absolute': 1,
#          'addition': 1,
#          'paid': 3,
#          'reasonable': 1,
#          'cent': 1,
#          'victim': 1,
#          'formula': 1,
#          'deserves': 1,
#          'applied': 1,
#          'calculating': 2,
#          'prospect': 1,
#          'based': 7,
#          'principle': 7,
#          'laid': 6,
#          'supra': 4,
#          'use': 1,
#          'dtc': 1,
#          'upheld': 3,
#          'mentioned': 3,
#          'column': 1,
#          'table': 1,
#          'prepared': 1,
#          'susamma': 1,
#          'thomas': 1,
#          'trilok': 1,
#          'chandra': 1,
#          'charlie': 1,
#          'starts': 1,
#          'operative': 1,
#          'groups': 1,
#          'unit': 1,
#          'units': 1,
#          'correct': 1,
#          'uphold': 1,
#          'purpose': 1,
#          'respect': 2,
#          'medical': 6,
#          'expenses': 5,
#          'incurred': 1,
#          'bills': 3,
#          'incidental': 3,
#          'charges': 3,
#          'marked': 5,
#          'exs': 2,
#          'prescriptions': 1,
#          'change': 1,
#          'artificial': 1,
#          'shall': 3,
#          'allot': 1,
#          'costs': 1,
#          'including': 2,
#          'works': 1,
#          'conventional': 2,
#          'heads': 6,
#          'litigation': 2,
#          'balram': 1,
#          'prasad': 1,
#          'kunal': 1,
#          'saha': 1,
#          'allow': 2,
#          'relying': 1,
#          'municipal': 1,
#          'corporation': 1,
#          'delhi': 2,
#          'association': 1,
#          'victims': 1,
#          'uphaar': 1,
#          'tragedy': 1,
#          'rate': 1,
#          'annum': 5,
#          'application': 4,
#          'payment': 3,
#          'type': 1,
#          'compound': 1,
#          'fracture': 7,
#          'tibia': 3,
#          'middle': 5,
#          'shaft': 1,
#          'fibula': 1,
#          'card': 1,
#          'photographs': 1,
#          'functional': 7,
#          'accidents': 1,
#          'particularly': 1,
#          'average': 1,
#          'recorded': 1,
#          'x18': 1,
#          'disputed': 1,
#          'producing': 2,
#          'constant': 1,
#          'reasoning': 2,
#          'identified': 1,
#          'cleaner': 3,
#          'lorries': 1,
#          '3rd': 3,
#          'humerus': 1,
#          'comminuted': 2,
#          'junction': 1,
#          'film': 1,
#          'calculated': 1,
#          'ascertaining': 1,
#          'able': 2,
#          'bend': 1,
#          'stretch': 1,
#          'rotate': 1,
#          'lift': 1,
#          'heavy': 1,
#          'essential': 1,
#          'observe': 3,
#          'lorry': 1,
#          'minimum': 2,
#          'written': 1,
#          'rounding': 1,
#          'added': 1,
#          'barter': 1,
#          'amounts': 1,
#          'applicable': 1,
#          'group': 1,
#          'pertinent': 2,
#          'treated': 1,
#          'inpatient': 1,
#          'days': 1,
#          'hospital': 1,
#          'conveyance': 1,
#          'nourishment': 1,
#          'attendant': 1,
#          'recovery': 1,
#          'health': 1,
#          'discomfort': 1,
#          'unhappiness': 1,
#          'undergo': 1,
#          'meager': 1,
#          'inadequate': 1,
#          'apart': 1,
#          'provided': 1,
#          'contributory': 4,
#          'negligence': 4,
#          'contribution': 2,
#          'utmost': 1,
#          'care': 1,
#          'moving': 2,
#          'highway': 1,
#          'looking': 1,
#          'spot': 1,
#          'concluded': 2,
#          'led': 1,
#          'charge': 1,
#          'sheeted': 1,
#          'sections': 1,
#          'ipc': 1,
#          'contributed': 1,
#          'concurred': 1,
#          'findings': 1,
#          'holding': 1,
#          'liable': 1,
#          'arrived': 1,
#          'took': 1,
#          'proved': 1,
#          'respondents': 1,
#          'finding': 1,
#          'set': 1,
#          'aside': 1,
#          'allowed': 1,
#          'accordingly': 1,
#          'erstwhile': 1,
#          'respondent': 2,
#          'deleted': 1,
#          'array': 1,
#          'parties': 1,
#          'remains': 1,
#          'sole': 1,
#          'direct': 1,
#          'deposit': 1,
#          'proportionate': 2,
#          'weeks': 3,
#          'receipt': 1,
#          'copy': 1,
#          'deducting': 1,
#          'nationalized': 1,
#          'bank': 1,
#          'choice': 1,
#          'want': 1,
#          'withdraw': 1,
#          'portion': 1,
#          'entire': 1,
#          'deposited': 2,
#          'personal': 1,
#          'development': 1,
#          'asset': 1,
#          'liberty': 1,
#          'file': 1,
#          'release': 1,
#          'pass': 1,
#          'appropriate': 1,
#          'rest': 1,
#          'way': 1,
#          'demand': 1,
#          'draft': 1,
#          'directed': 1,
#          'submit': 1,
#          'compliance': 1,
#          'report': 1,
#          'sudhansu': 1,
#          'jyoti': 1,
#          'mukhopadhaya': 1,
#          'january': 1})
